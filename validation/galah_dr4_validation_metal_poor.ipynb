# %%
# Preamble 
try:
    # %matplotlib inline
    # %config InlineBackend.figure_format='retina'
except:
    pass

from astropy.table import Table,join,hstack,vstack
import glob
import numpy as np
import matplotlib.pyplot as plt
import corner
from scipy.optimize import curve_fit

# %%
# First read in the unvalidated GALAH DR4 file
galah = Table.read('../spectrum_post_processing//galah_dr4_allspec_not_validated.fits')
#galah = galah[galah['flag_sp_fit'] == 0]

# %%
gaia_tmass = Table.read('../auxiliary_information/gaiadr3.gaia_source_xmatch_galah.fits')

# %%
gaia_tmass = Table.read('../auxiliary_information/dr60_gaiadr3_galahdr3_initial_params.fits')

# %%
star = dict()
star['sobject_id'] = 140116004301131

star['tmass_id'] = '09093943-2710562'
star['j_m'] = 11.37
star['j_msigcom'] = 0.024
star['h_m'] = 10.826
star['h_msigcom'] = 0.024
star['ks_m'] = 10.723
star['ks_msigcom'] = 0.02

star['source_id'] = 5648280704644030080
star['parallax'] = 0.153076867659948
star['parallax_error'] = 0.017221529
star['phot_g_mean_mag'] = 12.991653
star['phot_bp_mean_mag'] = 13.531368
star['phot_rp_mean_mag'] = 12.286386
star['grvs_mag'] = 11.961842
star['grvs_mag_error'] = 0.019825045

star['rv_gaia_dr3'] = 132.5862
star['e_rv_gaia_dr3'] = 1.0552768

star['rv_galah_dr4'] = 15.985965
star['e_rv_galah_dr4'] = 0.030876165

star['rv_galah_dr3'] = 131.53500366210938
star['e_rv_galah_dr3'] = 0.3199999928474426
# Out:
# <Table masked=True length=912275>
#    sobject_id       tmass_id     ... ebpminrp_gspphot_upper libname_gspphot
#                                  ...          mag
#      int64          bytes16      ...        float32              bytes7
# --------------- ---------------- ... ---------------------- ---------------
# 131216002601003 09524585+2600248 ...                    nan
# 131216003201003 09485609+1344395 ...                 0.0422           MARCS
# 131216002101248 07361252-5818329 ...                  0.059           MARCS
# 131216002101249 07383920-5836340 ...                 0.2946         PHOENIX
# 131216002101254 07373544-5824239 ...                    nan
# 131216002101255 07391784-5840040 ...                 0.1609           MARCS
# 131216002101256 07360541-5807358 ...                 0.4268           MARCS
# 131216002101257 07382314-5830149 ...                  0.381           MARCS
# 131216002101258 07385349-5834272 ...                 0.2395           MARCS
# ...
